# %% [markdown]
# Now that we've got IMDB IDs for nearly every show in our original scrape, let's get some additional info from IMDB that TVmaze couldn't provide. This includes stuff like actors, writers, and the IMDB score, which is likely more meaningful than the TVMaze result given the former's larger user base. We'll again need to use the custom wrapper and requests function to avoid overloading the server and breaking the pull.

# %%
import pandas as pd
import numpy as np
import requests
import time
import re
import yaml
import scrapy
import pickle
from functools import wraps
shows = pd.read_pickle("full_shows_tmp_1_tvmaze_plus_imdbids.pkl")
auth = yaml.load(open('omdb.yaml'))
key = auth['OMDB']['Key']

# %%
# A wrapper to retry the request function many times, with a sleep in between
def retry_multi(max_retries):
    """ Retry a function `max_retries` times. """
    def retry(func):
        @wraps(func)
        def wrapper(*args, **kwargs):
            num_retries = 0 
            while num_retries <= max_retries:
                try:
                    ret = func(*args, **kwargs)
                    break
                except:
                    if num_retries == max_retries:
                        raise
                    num_retries += 1
                    time.sleep(15)
            return ret 
        return wrapper
    return retry

# %%
# Bringing in our requester from the previous step (OMDB Initial Supplementation)
# But with the addition of functionality from ratelimit
#@sleep_and_retry
#@limits(calls=10,period=10)
@retry_multi(10)
def request_info(imdb_id):
    
    # define params for json request
    params = {'apikey':key,'i':imdb_id,'plot':'full'}

    # send request via requests
    try:
        response = requests.get('http://www.omdbapi.com/?',params=params,timeout=10)
        time.sleep(0.25)
    except:
        while num_tries <= 15:
            num_tries = 1
            response = requests.get('http://www.omdbapi.com/?',params=params,timeout=30)
            num_tries += 1
            time.sleep(1)
    
    if response.status_code != 200:
        raise Exception('API response: {}'.format(response.status_code))
    
    return response

# %%
def get_json(response):
    
    # Just return the json, if the search was successful
    if response.json()['Response'] == 'True':
        success = True
    elif response.json()['Response'] == 'False':
        success = False
        
    # Return a dict indicating success/failure of request, with json
    return {'json':response.json(),'success':success}

# %% [markdown]
# Looping through our results...

# %%
# This will be a list of the JSONs we receive
feed = []

# %%
for show in shows['imdb_id']:
    r = request_info(show)
    json = get_json(r)
    if json['success'] == True:
        print('Success: {}'.format(json['json']['Title']))
        feed.append(json['json'])
    else:
        print('Request worked, but show not found.')
# Out:
# Success: $#*! My Dad Says
# Success: 100 Code
# Success: 101 Ways to Leave a Gameshow
# Success: 12 Monkeys
# Success: 13 Reasons Why
# Success: 16 and Pregnant
# Success: 1600 Penn
# Success: 18 to Life
# Success: 17 Kids and Counting
# Success: 2 Broke Girls
# Success: 24
# Success: 24: Legacy
# Success: 24: Live Another Day
# Success: 3%
# Success: 30 Rock
# Success: 4th and Loud
# Success: 500 Questions
# Success: 60 Days In
# Success: 666 Park Avenue
# Success: 7 Little Johnstons
# Success: 9-1-1
# Success: 90210
# Success: 9JKL
# Success: Midnight, Texas
# Success: A Gifted Man
# Success: A Series of Unfortunate Events
# Success: A to Z
# Success: A Wicked Offer
# Success: A.D. The Bible Continues
# Success: A.P. Bio
# Success: Abby's Studio Rescue
# Success: About a Boy
# Success: Absentia
# Success: Accidentally on Purpose
# Success: According to Jim
# Success: Ace of Cakes
# Success: Adam Devine's House Party
# Success: Adventure Time
# Success: After Lately
# Success: Aftermath
# Success: Against the Wall
# Success: Agent X
# Success: Alaska State Troopers
# Success: Alcatraz
# Success: Alex, Inc.
# Success: Alexa & Katie
# Success: All My Children
# Success: Allegiance
# Success: Allen Gregory
# Success: Almost Human
# Success: Almost Royal
# Success: Alone Together
# Success: Alphas
# Success: Altered Carbon
# Success: America's Got Talent
# Success: America's Best Dance Crew
# Success: America's Most Wanted: America Fights Back
# Success: America's Next Great Restaurant
# Success: America's Next Top Model
# Success: American Chopper: The Series
# Success: American Crime
# Success: American Crime Story
# Success: American Dad!
# Success: American Dream Builders
# Success: American Gods
# Success: American Gothic
# Success: American Grit
# Success: American Guns
# Success: American Horror Story
# Success: American Housewife
# Success: American Idol
# Success: American Ninja Warrior
# Success: American Odyssey
# Success: American Pickers
# Success: American Playboy: The Hugh Hefner Story
# Success: American Vandal
# Success: Amish Mafia
# Success: Andi Mack
# Success: Angel from Hell
# Success: Anger Management
# Success: Angie Tribeca
# Success: Animal Kingdom
# Success: Animal Practice
# Success: Anne with an E
# Success: Another Period
# Success: Anthony Bourdain: Parts Unknown
# Success: APB
# Success: Aqua Teen Hunger Force
# Success: Aquarius
# Success: Archer
# Success: Are We There Yet?
# Success: Are You Smarter Than a 5th Grader?
# Success: Are You the One?
# Success: Are You There, Chelsea?
# Success: Army Wives
# Success: Arrested Development
# Success: Arrow
# Success: As the World Turns
# Success: Ash vs Evil Dead
# Success: At Home with Amy Sedaris
# Success: Atlanta
# Success: Atlantis
# Success: Atypical
# Success: Auction Hunters
# Success: Austin & Ally
# Success: Awake
# Success: Awkward.
# Success: Baby Daddy
# Success: After Paradise
# Success: Bachelor Pad
# Success: Back
# Success: Back in the Game
# Success: Backpackers
# Success: Backstrom
# Success: Bad Girls Club
# Success: Bad Judge
# Success: Bad Teacher
# Success: Ballers
# Success: Banshee
# Success: Bar Rescue
# Success: Barely Famous
# Success: Barry
# Success: Barry'd Treasure
# Success: Basketball Wives
# Success: Basketball Wives LA
# Success: Baskets
# Success: Bates Motel
# Success: Battle Creek
# Success: Battle of the Network Stars
# Success: BattleBots
# Success: Battlestar Galactica
# Success: Beat Shazam
# Success: Beauty and the Beast
# Success: Becoming Us
# Success: Being Erica
# Success: Being Human
# Success: Being Mary Jane
# Success: Believe
# Success: Bellevue
# Success: Below Deck
# Success: Ben and Kate
# Success: Ben & Lauren: Happily Ever After?
# Success: Benched
# Success: Bent
# Success: Beowulf: Return to the Shieldlands
# Success: Berlin Station
# Success: Best Friends Forever
# Success: Best Friends Whenever
# Success: Best Ink
# Success: Best Time Ever with Neil Patrick Harris
# Success: Bet on Your Baby
# Success: Bethenny & Fredrik
# Success: Bethenny Ever After
# Success: Betrayal
# Success: Better Call Saul
# Success: Better Late Than Never
# Success: Better Off Ted
# Success: Better Things
# Success: Better with You
# Success: Betty White's Off Their Rockers
# Success: Between
# Success: Beverly Hills Nannies
# Success: Beyond
# Success: Big Brother
# Success: Big Little Lies
# Success: Big Love
# Success: Big Mouth
# Success: Big Star Little Star
# Success: Bill Nye Saves the World
# Success: Billions
# Success: Billy on the Street with Billy Eichner
# Success: Billy the Exterminator
# Success: Bionic Woman
# Success: Bitten
# Success: Black Box
# Success: Black Gold
# Success: Black Ink Crew
# Success: Black Lightning
# Success: Black Mirror
# Success: Black Sails
# Success: Black-ish
# Success: Blindspot
# Success: Blood & Oil
# Success: Blood Drive
# Success: Bloodline
# Success: Blue Bloods
# Success: Blue Mountain State
# Success: Blunt Talk
# Success: Boardwalk Empire
# Success: Bob's Burgers
# Success: Body of Proof
# Success: BoJack Horseman
# Success: Bomb Girls
# Success: Bones
# Success: Sonic Boom
# Success: Bordertown
# Success: Bored to Death
# Success: Born Again Virgin
# Success: Born This Way
# Success: Bosch
# Success: Boss
# Success: Shut Up Flower Boy Band
# Success: BrainDead
# Success: Brand X with Russell Brand
# Success: Brandi and Jarrod: Married to the Job
# Success: Braxton Family Values
# Success: Breaking Amish
# Success: Breaking Bad
# Success: Breaking Boston
# Success: Breaking In
# Success: Breaking Pointe
# Success: Breakout Kings
# Success: Bring It!
# Success: Broad City
# Success: Broadchurch
# Success: Brockmire
# Success: Brooklyn Nine-Nine
# Success: Property Brothers
# Success: Brothers & Sisters
# Success: Buckwild
# Success: Bull
# Success: Bullseye
# Success: Bunheads
# Success: Bunk'd
# Success: Burden of Truth
# Success: Buried Treasure
# Success: Burn Notice
# Success: Cake Boss
# Success: Californication
# Success: Camelot
# Success: Camp
# Success: Candidly Nicole
# Success: Candy Crush
# Success: Cane
# Success: Caprica
# Success: The Capture of the Green River Killer
# Success: Cardinal
# Success: Cash Cab
# Success: Castle
# Success: Castlevania
# Success: Casual
# Success: Catastrophe
# Success: Catch a Contractor
# Success: Catfish: The TV Show
# Success: Cedar Cove
# Success: Cedric's Barber Battle
# Success: Ceelo Green's the Good Life
# Success: Celebrity Big Brother
# Success: Celebrity Family Feud
# Success: Celebrity Rehab with Dr. Drew
# Success: Celebrity Wife Swap
# Success: Champions
# Success: Chance
# Success: Channel Zero
# Success: Chaos
# Success: Charlie's Angels
# Success: The Chase
# Success: Chasing Life
# Success: Cheer Perfection
# Success: Cheer Squad
# Success: Chef Roble & Co.
# Success: Chef's Table
# Success: Chelsea
# Success: Chesapeake Shores
# Success: Chicago Fire
# Success: Chicago Justice
# Success: Chicago Med
# Success: Chicago P.D.
# Success: Child Support
# Success: Childrens Hospital
# Success: Chozen
# Success: Chrisley Knows Best
# Success: Chuck
# Success: Claws
# Success: Clipped
# Success: Code Black
# Success: Cold Case
# Success: Cold Case Files
# Success: Cold Justice
# Success: Colony
# Success: Combat Hospital
# Success: Comedy Bang! Bang!
# Success: Comic Book Men
# Success: Common Law
# Success: Community
# Success: Complications
# Success: Conan
# Success: Condor
# Success: Constantine
# Success: Containment
# Success: Continuum
# Success: Conviction
# Success: Cooper Barrett's Guide to Surviving Life
# Success: Copper
# Success: Cops
# Success: Corporate
# Success: Cosmos: A Spacetime Odyssey
# Success: Cougar Town
# Success: Counterpart
# Success: Coupled
# Success: Covert Affairs
# Request worked, but show not found.
# Success: Crashing
# Success: Crazy Ex-Girlfriend
# Success: Criminal Minds
# Success: Criminal Minds: Beyond Borders
# Success: Criminal Minds: Suspect Behavior
# Success: Crisis
# Success: Crisis in Six Scenes
# Success: Criss Angel Mindfreak
# Success: Cristela
# Success: Crossbones
# Success: Crossing Lines
# Success: Crowded
# Success: CSI: Crime Scene Investigation
# Success: CSI: Cyber
# Success: CSI: Miami
# Success: CSI: NY
# Success: Cult
# Success: Cupid
# Success: Curb Your Enthusiasm
# Success: Da Vinci's Demons
# Success: The Grill Dads
# Success: Dallas
# Success: Damages
# Success: Damien
# Success: Damnation
# Success: Dan for Mayor
# Success: Dance Moms
# Success: Dance Moms: Miami
# Success: Dancing with the Stars
# Success: Daredevil
# Success: Dark
# Success: Dark Blue
# Success: Dark Matter
# Success: Dark Net
# Success: First Dates
# Success: Dating in the Dark
# Success: Dating Naked
# Success: Days of Our Lives
# Success: Daytime Divas
# Success: Legends of Tomorrow
# Success: Dead of Summer
# Success: Deadbeat
# Success: Deadliest Catch
# Success: Deal with It
# Success: Dear White People
# Success: Death Valley
# Success: Deception
# Success: Deception
# Success: Defiance
# Success: Defying Gravity
# Success: Designated Survivor
# Success: Desperate Housewives
# Success: Destination Truth
# Success: Detroit Steel
# Success: Devious Maids
# Success: Dexter
# Success: Dice
# Success: Dietland
# Success: Difficult People
# Success: Dig
# Success: Dirk Gently's Holistic Detective Agency
# Success: Dirty Jobs
# Success: Dirty Sexy Money
# Success: Disjointed
# Success: Divorce
# Success: Do No Harm
# Success: Documentary Now!
# Success: Does Someone Have to Go?
# Success: Dog the Bounty Hunter
# Success: Dog with a Blog
# Success: Dogs in the City
# Success: Dollhouse
# Success: Dominion
# Success: Don't Trust the B---- in Apartment 23
# Success: Donny!
# Success: Doubt
# Success: Downton Abbey
# Success: Downward Dog
# Success: Dr. Ken
# Success: Dracula
# Success: Drop Dead Diva
# Success: Drop the Mic
# Success: Drunk History
# Success: Duck Dynasty
# Success: Duets
# Success: Dynasty
# Success: Eagleheart
# Success: East Los High
# Success: Eastbound & Down
# Success: Eastwick
# Success: Easy
# Success: Philip K. Dick's Electric Dreams
# Success: Elementary
# Success: Eleventh Hour
# Success: Eli Stone
# Success: Ellen's Game of Games
# Success: Emerald City
# Success: Emily Owens M.D.
# Success: Empire
# Success: Endgame
# Success: Enlightened
# Success: Enlisted
# Success: Entourage
# Success: Episodes
# Success: Eureka
# Success: Everwood
# Success: Everything Sucks!
# Success: Expedition Impossible
# Success: Extant
# Success: Extreme Couponing
# Success: Extreme Makeover: Home Edition
# Success: Extreme Weight Loss
# Success: Eye Candy
# Success: Eyewitness
# Success: F Is for Family
# Success: FabLife
# Success: Game Face
# Success: Fact or Faked: Paranormal Files
# Success: Fairly Legal
# Success: Faking It
# Success: Falling Skies
# Success: Falling Water
# Success: Fameless
# Success: Family Guy
# Success: Family S.O.S. With Jo Frost
# Success: Family Tools
# Success: Family Tree
# Success: Famous in 12
# Success: Famous in Love
# Success: Fargo
# Success: Fashion Star
# Success: Fear Factor
# Success: Fear the Walking Dead
# Success: Feed the Beast
# Success: Feud
# Success: Finding Bigfoot
# Success: Finding Carter
# Success: Finding Prince Charming
# Success: Flaked
# Success: Flashforward
# Success: Flashpoint
# Success: Fleabag
# Success: Flesh and Bone
# Success: Flight of the Conchords
# Success: MTV Floribama Shore
# Success: Flying Wild Alaska
# Success: Food Fighters
# Success: For the People
# Success: Forever
# Success: Four Weddings
# Success: Franklin & Bash
# Success: Freakish
# Success: Free Agents
# Success: Frequency
# Success: Fresh Off the Boat
# Success: Friday Night Lights
# Success: Friends from College
# Success: Friends with Benefits
# Success: Friends with Better Lives
# Success: Fringe
# Success: From Dusk Till Dawn: The Series
# Success: Frontier
# Success: Full Frontal with Samantha Bee
# Success: Full Throttle Saloon
# Success: Fuller House
# Success: Futurama
# Success: Future Man
# Success: Galavant
# Success: Game of Arms
# Success: Game of Silence
# Success: Game of Thrones
# Success: Gang Related
# Success: Garfunkel and Oates
# Success: Gary Unmarried
# Success: Gator Boys
# Success: GCB
# Success: Gene Simmons: Family Jewels
# Success: Genius
# Success: Genius Junior
# Success: Get Out Alive with Bear Grylls
# Success: Get Shorty
# Success: Getting On
# Success: Ghost Hunters
# Success: Ghost Hunters International
# Success: Ghost Mine
# Success: Ghost Wars
# Success: Ghost Whisperer
# Success: Ghosted
# Success: Gigi Does It
# Success: Gigolos
# Success: Gilmore Girls
# Success: Gilmore Girls: A Year in the Life
# Success: Girl Meets World
# Success: Girlboss
# Success: Girlfriends' Guide to Divorce
# Success: Girls
# Success: Glee
# Success: Glitch
# Success: Glory Daze
# Success: GLOW
# Success: Go On
# Success: Godless
# Success: Golan the Insatiable
# Success: Gold Rush: Alaska
# Success: Golden Boy
# Success: Goliath
# Success: Good Behavior
# Success: Good Girls
# Success: Good Girls Revolt
# Success: Good Luck Charlie
# Success: Good Witch
# Success: Gordon Ramsay's 24 Hours to Hell & Back
# Success: Gossip Girl
# Success: Gotham
# Success: Grace and Frankie
# Success: Graceland
# Success: Gracepoint
# Success: Grandfathered
# Success: Graves
# Success: Gravity
# Success: Gravity Falls
# Success: Great News
# Success: Greek
# Success: Greenleaf
# Success: Grey's Anatomy
# Success: Grimm
# Success: Ground Floor
# Success: Growing Up Fisher
# Success: Grown-ish
# Success: Guilt
# Success: Guys with Kids
# Success: Gypsy
# Success: Gypsy Sisters
# Success: H8R
# Success: Halt and Catch Fire
# Success: Hand of God
# Success: Hank Zipzer
# Success: Hannibal
# Success: Hap and Leonard
# Success: Happily Divorced
# Success: Happy Endings
# Success: Happy Town
# Success: Happy!
# Success: Happyish
# Success: Happyland
# Success: Hard Sun
# Success: Hardcore Pawn
# Success: Harlots
# Success: Harper's Island
# Success: Harry's Law
# Success: Hart of Dixie
# Success: Haters Back Off!
# Success: Haven
# Success: Hawaii Five-0
# Success: Hawthorne
# Success: Heartbeat
# Success: Heathers
# Success: Helix
# Success: Hell on Wheels
# Success: Hell's Kitchen
# Success: Hellcats
# Success: Hello Ladies
# Success: Hemlock Grove
# Success: Here and Now
# Success: Here Comes Honey Boo Boo
# Success: Heroes
# Success: Heroes Reborn
# Success: High Maintenance
# Success: Hindsight
# Success: Hip Hop Squares
# Success: Hit the Floor
# Success: Hit the Road
# Success: Hoarders
# Success: Hoarding: Buried Alive
# Success: Hollywood Game Night
# Success: Hollywood Heights
# Success: Hollywood Treasure
# Success: Home Free
# Success: Homeland
# Success: Hooten & the Lady
# Success: Hostages
# Success: Hot in Cleveland
# Success: Hotel Hell
# Success: Houdini and Doyle
# Success: House
# Success: House of Cards
# Success: House of Lies
# Success: House of Payne
# Success: How I Met Your Mother
# Success: How to Be a Gentleman
# Success: How to Get Away with Murder
# Success: How to Live with Your Parents (For the Rest of Your Life)
# Success: How to Make It in America
# Success: Huge
# Success: Human Target
# Success: Humans
# Success: Hung
# Success: Hunted
# Success: Hunters
# Success: I Am Cait
# Success: I am Frankie
# Success: I Am Jazz
# Success: I Can Do That!
# Success: I Didn't Know I Was Pregnant
# Success: I Hate My Teenage Daughter
# Success: I Just Want My Pants Back
# Success: I Love Dick
# Success: I Wanna Marry 'Harry'
# Success: I'm Dying Up Here
# Success: I'm Sorry
# Success: iCarly
# Success: Ice
# Success: Ice Road Truckers
# Success: Idiotsitter
# Success: Imaginary Mary
# Success: Impastor
# Success: Imposters
# Success: Impractical Jokers
# Success: In Plain Sight
# Success: In the Motherhood
# Success: In Treatment
# Success: Incorporated
# Success: Ink Master
# Request worked, but show not found.
# Success: Insecure
# Success: Inside Amy Schumer
# Success: Inside Comedy
# Success: Instant Mom
# Success: Instinct
# Success: Intelligence
# Success: Intervention
# Success: Into the Badlands
# Success: Intruders
# Success: Invasion
# Success: Iron Fist
# Success: Ironside
# Success: It's Always Sunny in Philadelphia
# Success: It's Worth What?
# Success: iZombie
# Success: Food Revolution
# Success: Jane by Design
# Success: Jane the Virgin
# Success: Jean-Claude Van Johnson
# Success: Jennifer Falls
# Success: Jericho
# Success: Jersey Couture
# Success: Jersey Shore
# Success: Jersey Shore Family Vacation
# Success: Jerseylicious
# Success: Jessica Jones
# Success: Jessie
# Success: Jim Henson's Creature Shop Challenge
# Success: Joey
# Success: Justified
# Success: K.C. Undercover
# Success: Jon & Kate Plus 8
# Success: Kath & Kim
# Success: Kathy Griffin: My Life on the D-List
# Success: Alexa & Katie
# Success: Kevin (Probably) Saves the World
# Success: Kevin Can Wait
# Success: Kevin from Work
# Success: Key and Peele
# Success: Kicking & Screaming
# Success: Killer Women
# Success: Killing Eve
# Success: Killjoys
# Success: Kim of Queens
# Success: Janet King
# Success: King & Maxwell
# Success: King of the Hill
# Success: King of the Nerds
# Success: Kingdom
# Success: Pool Kings
# Success: Kirstie
# Success: Kitchen Nightmares
# Success: Knight Rider
# Success: Knightfall
# Success: Knock Knock Live
# Success: Kocktails with Khloé
# Success: Kroll Show
# Success: Krypton
# Success: LA Ink
# Success: LA to Vegas
# Success: Lachey's Bar
# Success: Ladies of London
# Success: Lady Dynamite
# Success: Last Call with Carson Daly
# Success: Last Chance U
# Success: Last Comic Standing
# Success: Last Man Standing
# Success: Last Resort
# Success: Last Week Tonight with John Oliver
# Success: Late Night with Jimmy Fallon
# Success: Law & Order
# Success: Law & Order True Crime
# Success: Law & Order: Criminal Intent
# Success: Law & Order: LA
# Success: Law & Order: Special Victims Unit
# Success: Leah Remini: It's All Relative
# Success: Leah Remini: Scientology and the Aftermath
# Success: Legend of the Seeker
# Success: Legends
# Success: Legion
# Success: Legit
# Success: Let's Get Physical
# Success: Let's Stay Together
# Success: Lethal Weapon
# Success: Leverage
# Success: Liar
# Success: Lie to Me
# Success: Life
# Success: Life in Pieces
# Success: Life Sentence
# Success: Life Unexpected
# Success: Lights Out
# Success: Lilyhammer
# Success: Limitless
# Success: Lip Sync Battle
# Success: Lipstick Jungle
# Success: Little Big Shots
# Success: Little People, Big World
# Success: Little Women: LA
# Success: Little Women: NY
# Success: Liv and Maddie
# Success: Live to Dance
# Success: Living Biblically
# Success: Lizard Lick Towing
# Success: Loaded
# Success: Lone Star Law
# Success: Long Island Medium
# Success: Longmire
# Success: Looking
# Success: *Loosely Exactly Nicole
# Success: Lopez
# Success: Lopez Tonight
# Success: Lore
# Success: Lost
# Success: Lost Girl
# Success: Lost in Space
# Success: Loudermilk
# Success: Louie
# Success: Love
# Success: Love & Hip Hop: Atlanta
# Success: Love & Hip Hop: Atlanta
# Success: Love & Hip Hop: Hollywood
# Success: Love at First Kiss
# Success: Love Bites
# Success: Love Connection
# Success: Love in the Wild
# Success: To Love is Forever
# Success: Love You, Mean It with Whitney Cummings
# Success: Lovesick
# Success: Low Winter Sun
# Success: Lucas Bros Moving Co
# Success: Lucha Underground
# Success: Lucifer
# Success: Luck
# Success: Lucky 7
# Success: Luke Cage
# Success: Luther
# Success: MacGyver
# Success: Mad Dogs
# Success: Mad Love
# Success: Mad Men
# Success: The TV That Made Me
# Success: Madam Secretary
# Success: Made in Jersey
# Success: Magic City
# Success: Major Crimes
# Success: Make It or Break It
# Success: Making a Murderer
# Success: Making History
# Success: Malibu Country
# Success: Mama June: From Not to Hot
# Success: Man Seeking Woman
# Success: Man Up
# Success: Man with a Plan
# Success: Manhattan
# Success: Manhattan Love Story
# Success: Manhunters: Fugitive Task Force
# Success: Marco Polo
# Success: Mariah's World
# Success: Marlon
# Success: Maron
# Success: Married
# Success: Married at First Sight
# Success: Marry Me
# Success: Mars
# Success: Martha & Snoop's Potluck Dinner Party
# Success: Agent Carter
# Success: Agents of S.H.I.E.L.D.
# Success: Inhumans
# Success: Runaways
# Success: The Defenders
# Success: The Punisher
# Success: Being Mary Jane
# Success: Mary Kills People
# Success: Master of None
# Success: Masterchef
# Success: MasterChef Junior
# Success: Masters of Illusion
# Success: Masters of Sex
# Success: Match Game
# Success: Maya & Marty
# Success: McMafia
# Success: Me, Myself and I
# Success: Medium
# Success: Melissa & Joey
# Success: Melrose Place
# Success: Memphis Beat
# Success: Men at Work
# Success: Men in Trees
# Success: Men of a Certain Age
# Success: Mental
# Success: Mercy
# Success: Mercy Street
# Success: Merlin
# Success: Meteorite Men
# Success: Miami Medical
# Success: Midnight, Texas
# Success: Mike & Molly
# Success: Million Dollar Listing NY
# Success: Million Dollar Listing Miami
# Success: Million Dollar Listing NY
# Success: Million Dollar Listing San Francisco
# Success: Mind Games
# Success: Mindhunter
# Success: Minority Report
# Success: Minute to Win It
# Success: The Missing
# Success: Mistresses
# Success: Mixology
# Success: Mob City
# Success: Mob Wives
# Success: Mobbed
# Success: Modern Family
# Success: Mom
# Success: Monday Mornings
# Success: Monica the Medium
# Success: Monk
# Success: Moonlight
# Success: Moonshiners
# Success: Mosaic
# Success: Motive
# Success: Mozart in the Jungle
# Success: Mr. Mercedes
# Success: Mr. Robinson
# Success: Mr. Robot
# Success: Mr. Sunshine
# Success: Mulaney
# Success: Murder in the First
# Success: Murdoch Mysteries
# Success: Murphy Brown
# Success: My Big Fat Fabulous Life
# Success: My Boys
# Success: My Crazy Obsession
# Success: My Diet Is Better Than Yours
# Success: My Five Wives
# Success: My Generation
# Success: My Kitchen Rules
# Success: My Name Is Earl
# Success: My Own Worst Enemy
# Success: Mystery Girls
# Success: Mystery Science Theater 3000: The Return
# Success: MythBusters
# Success: Naked and Afraid
# Success: Napoleon Dynamite
# Success: Narcos
# Success: Nashville
# Success: Nate & Jeremiah by Design
# Success: NCIS
# Success: NCIS: Los Angeles
# Success: NCIS: New Orleans
# Success: Necessary Roughness
# Success: Neighbors with Benefits
# Success: New Girl
# Success: Cake Boss: Next Great Baker
# Success: Nicky, Ricky, Dicky & Dawn
# Success: Nightcap
# Success: Nightwatch
# Success: Nikita
# Success: No Activity
# Success: No Ordinary Family
# Success: No Tomorrow
# Success: Nobodies
# Success: Not Safe with Nikki Glaser
# Success: Notorious
# Success: Numb3rs
# Success: Nurse Jackie
# Success: NY Ink
# Success: NY Med
# Success: NYC 22
# Success: Odd Mom Out
# Success: Of Kings and Prophets
# Success: Off the Map
# Success: Oh Sit!
# Success: Olympus
# Success: On My Block
# Success: On the Menu
# Success: Once Upon a Time
# Success: Once Upon a Time in Wonderland
# Success: One Big Happy
# Success: One Born Every Minute
# Success: One Day at a Time
# Success: One Life to Live
# Success: One Mississippi
# Success: One Tree Hill
# Success: Only in America with Larry the Cable Guy
# Success: Operation Repo
# Success: Opposite Worlds
# Success: Orange Is the New Black
# Success: Orphan Black
# Success: Our Cartoon President
# Success: Outcast
# Success: Outlander
# Success: Outlaw Tech
# Success: Outsiders
# Success: Outsourced
# Success: Ozark
# Success: Ozzy & Jack's World Detour
# Success: Pan Am
# Success: Panic 9-1-1
# Success: Paranormal State
# Success: Paranormal Witness
# Success: Parenthood
# Success: Parks and Recreation
# Success: Partners
# Success: Party Down
# Success: Party Down South
# Success: Past Life
# Success: Patriot
# Success: Pawn Stars
# Success: Penn & Teller: Fool Us
# Success: Penny Dreadful
# Success: People of Earth
# Success: Perception
# Success: Perfect Couples
# Success: Perfect Score
# Success: Person of Interest
# Success: Phineas and Ferb
# Success: Pit Boss
# Success: Pitch
# Success: Plain Jane
# Success: Playing House
# Success: Please Like Me
# Success: Portlandia
# Success: Pose
# Success: Power
# Success: Powerless
# Success: Powers
# Success: Preacher
# Success: Preachers of LA
# Success: Pregnant in Heels
# Success: Pretty Little Liars
# Success: Prime Suspect
# Success: Prison Break
# Success: Private Eyes
# Success: Private Practice
# Success: Privileged
# Success: Project Greenlight
# Success: Project Runway
# Success: Project Runway Junior
# Success: Proof
# Success: Psych
# Success: Public Morals
# Success: Pure Genius
# Success: Pushing Daisies
# Success: Quantico
# Success: Quarry
# Success: Queen of the South
# Success: Queen Sugar
# Success: Queens of Drama
# Success: Queer Eye for the Straight Guy
# Success: Quick Draw
# Success: Raising Asia
# Success: Raising Hope
# Success: Rake
# Success: Ransom
# Success: Raven's Home
# Success: Ravenswood
# Success: Ray Donovan
# Success: Ready for Love
# Success: Real Rob
# Success: Real Time with Bill Maher
# Success: The Reaper
# Success: Reckless
# Success: Recovery Road
# Success: Rectify
# Success: Red Band Society
# Success: Red Oaks
# Success: Red Widow
# Success: Reign
# Success: Rellik
# Success: Reno 911!
# Success: Repeat After Me
# Success: Rescue Me
# Success: Resurrection
# Success: Retired at 35
# Success: Revenge
# Success: Reverie
# Success: Revolution
# Success: Rick and Morty
# Success: Ride with Norman Reedus
# Success: Ringer
# Success: Riot
# Success: Ripper Street
# Success: Rise
# Success: Rising Star
# Success: Rita Rocks
# Success: Riverdale
# Success: Rizzoli & Isles
# Success: Roadies
# Success: Rob
# Success: Robot Chicken
# Success: Rock Center with Brian Williams
# Success: Rogue
# Success: Romantically Challenged
# Success: Rookie Blue
# Success: Room 104
# Success: Roseanne
# Success: Roseanne's Nuts
# Success: Rosewood
# Success: Royal Pains
# Success: Rubicon
# Success: Rules of Engagement
# Success: Running Wild with Bear Grylls
# Success: Running Wilde
# Success: RuPaul's Drag Race
# Success: RuPaul's Drag Race All Stars
# Success: Rush
# Success: Rush Hour
# Success: S.W.A.T.
# Success: Safe
# Success: Salem
# Success: Salvation
# Success: Sam & Cat
# Success: Samantha Who?
# Success: Same Name
# Success: Sanctuary
# Success: Santa Clarita Diet
# Success: Sarah Palin's Alaska
# Success: Satisfaction
# Success: Saturday Night Live
# Success: Save Me
# Success: Saving Grace
# Success: Saving Hope
# Success: Say Yes to the Dress: Atlanta
# Success: Say Yes to the Dress: Bridesmaids
# Success: Scandal
# Success: Scare Tactics
# Success: Schitt's Creek
# Success: School of Rock
# Success: Scorpion
# Success: Scoundrels
# Success: Scream Queens
# Success: Scream Queens
# Success: Scrubs
# Success: SEAL Team
# Success: Sean Saves the World
# Success: Search Party
# Success: Second Chance
# Success: Secret Millionaire
# Success: Secrets and Lies
# Success: See Dad Run
# Success: Seed
# Success: Selfie
# Success: Selling New York
# Success: Sense8
# Success: Seven Seconds
# Success: Sex&Drugs&Rock&Roll
# Success: Sexy Beasts
# Success: Shades of Blue
# Success: Shadowhunters: The Mortal Instruments
# Success: Shahs of Sunset
# Success: Shake It Up
# Success: Shameless
# Success: Shaq vs
# Success: Shark Tank Australia
# Success: Sharp Objects
# Success: She's Gotta Have It
# Success: Shedding for the Wedding
# Success: Sherlock
# Success: Shooter
# Success: Shots Fired
# Success: Showtime at the Apollo
# Success: Shut Eye
# Success: Siberia
# Success: Siesta Key
# Success: Significant Mother
# Success: Silicon Valley
# Success: Sing Your Face Off
# Success: Single Ladies
# Success: Siren
# Success: Sirens
# Success: Sister Wives
# Success: Six
# Success: Skating with the Stars
# Success: Skins
# Success: Slasher
# Success: Sleepy Hollow
# Success: Small Town Security
# Success: Smallville
# Success: Smash
# Success: SMILF
# Success: Snatch
# Success: Sneaky Pete
# Success: Snoop Dogg presents the Joker's Wild
# Success: Snowfall
# Success: So You Think You Can Dance
# Success: So You Think You Can Dance Canada
# Success: Something Borrowed, Something New
# Success: Somewhere Between
# Success: Son of Zorn
# Success: Sons of Anarchy
# Success: Sons of Guns
# Success: Sons of Tucson
# Success: South Beach Tow
# Success: South of Hell
# Success: South Park
# Success: Southern Charm
# Success: Southland
# Success: Spartacus: War of the Damned
# Success: Spartan: Ultimate Team Challenge
# Success: Speechless
# Success: Splash!
# Success: Splitting Up Together
# Success: SpongeBob SquarePants
# Success: Stalker
# Success: Stan Against Evil
# Success: Star
# Success: Star Trek: Discovery
# Success: Still Star-Crossed
# Success: Stargate: Atlantis
# Success: Stargate SG-1
# Success: SGU Stargate Universe
# Success: Stars Earn Stripes
# Success: Starter Wives Confidential
# Success: StartUp
# Success: State of Affairs
# Success: State of Georgia
# Success: Station 19
# Success: Steve Harvey's Funderdome
# Success: Stewarts & Hamiltons
# Success: Still Star-Crossed
# Success: Still the King
# Success: Stitchers
# Success: Storage Wars
# Success: Strange Angel
# Success: Strange Sex
# Success: Stranger Things
# Success: Strike Back
# Success: Strong Woman Do Bong-soon
# Success: Strut
# Success: Stuck in the Middle
# Success: Suburgatory
# Success: Succession
# Success: Suddenly Royal
# Success: Suits
# Success: Sullivan & Son
# Success: Sun Records
# Success: Super Fun Night
# Success: Supergirl
# Success: Superhuman
# Success: Superior Donuts
# Success: Supernanny
# Success: Supernatural
# Success: Superstition
# Success: Superstore
# Success: Surviving Jack
# Success: Surviving Suburbia
# Success: Survivor
# Success: Survivor's Remorse
# Success: Swamp Loggers
# Success: Sweet/Vicious
# Success: Switched at Birth
# Success: SWV Reunited
# Success: Tabatha's Salon Takeover
# Success: Taboo
# Success: Take It All
# Success: Take Me Out
# Success: Take the Money & Run
# Success: Take Two with Phineas and Ferb
# Success: Taken
# Success: Tales
# Success: Tattoo Nightmares
# Success: Taxi Brooklyn
# Success: Teach: Tony Danza
# Success: Teachers
# Success: Teen Mom
# Success: Teen Mom 2
# Success: Teen Mom 3
# Success: Teen Wolf
# Success: Telenovela
# Success: Ten Days in the Valley
# Success: Terminator: The Sarah Connor Chronicles
# Success: Terra Nova
# Success: Terriers
# Success: That '70s Show
# Success: That Awkward Game Show
# Success: The $100,000 Pyramid
# Success: The 100
# Success: The 4400
# Success: The A Word
# Success: The Affair
# Success: The Alienist
# Success: The Amazing Race
# Success: The Amazing Race Canada
# Success: The American Baking Competition
# Success: The Americans
# Success: The Apprentice UK
# Success: The Arrangement
# Success: The Arsenio Hall Show
# Success: The Art of More
# Success: The Assets
# Success: The Astronaut Wives Club
# Success: The Awesomes
# Success: The Bachelor
# Success: The Bachelor Winter Games
# Success: The Bachelorette
# Success: The Bastard Executioner
# Success: The Beautiful Life: TBL
# Success: The Big Bang Theory
# Success: The Big C
# Success: The Biggest Loser Australia
# Success: The Birthday Boys
# Success: The Blacklist
# Success: The Blacklist: Redemption
# Success: The Bold Type
# Success: The Borgias
# Success: The Brave
# Success: The Breaks
# Success: The Bridge
# Success: The Bridge
# Success: The Briefcase
# Success: The Brink
# Success: The Buried Life
# Success: The Cape
# Success: The Carmichael Show
# Success: The Carrie Diaries
# Success: The Catalina
# Success: The Catch
# Success: The Apprentice
# Success: The Chair
# Success: The Chew
# Success: The Chi
# Success: The Chicago Code
# Success: The Choice
# Success: The Cleaner
# Success: The Cleveland Show
# Success: The Client List
# Success: The Closer
# Success: The Collection
# Success: The Comeback
# Success: The Comedians
# Success: The Crazy Ones
# Success: The Crossing
# Success: The Crown
# Success: The Dead Zone
# Success: The Defenders
# Success: The Detour
# Success: The Deuce
# Success: The Divide
# Success: The End of the F***ing World
# Success: The Event
# Success: The Exes
# Success: The Exorcist
# Success: The Expanse
# Success: The F Word
# Success: Game Face
# Success: The Family
# Success: The Finder
# Success: The Firm
# Success: The First 48
# Success: The Flash
# Success: The Following
# Success: The Forgotten
# Success: The Fosters
# Success: The Four: Battle for Stardom
# Success: The Game
# Success: The Gates
# Success: The Get Down
# Success: The Gifted
# Success: The Girlfriend Experience
# Success: The Glades
# Success: The Glass House
# Success: The Goldbergs
# Success: The Gong Show
# Success: The Good Doctor
# Success: The Good Fight
# Success: The Good Guys
# Success: The Good Place
# Success: The Good Wife
# Success: The Goode Family
# Success: The Goodwin Games
# Success: The Great Holiday Baking Show
# Success: The Great Christmas Light Fight
# Success: The Great Escape
# Success: The Great Indoors
# Success: The Grinder
# Success: The Guest Book
# Success: The Handmaid's Tale
# Success: The Hard Times of RJ Berger
# Success: The Hasselhoffs
# Success: The Hills
# Success: The Inbetweeners
# Success: The Insider
# Success: The Island
# Success: The Tonight Show with Jay Leno
# Success: The Jeff Probst Show
# Success: The Jim Gaffigan Show
# Success: The Jim Jefferies Show
# Success: The Job
# Success: The Joel McHale Show with Joel McHale
# Success: The Kandi Factory
# Success: The Killing
# Success: The Knick
# Success: The L.A. Complex
# Success: The Last Kingdom
# Success: The Last Man on Earth
# Success: The Last O.G.
# Success: The Last Ship
# Success: The Last Tycoon
# Success: The League
# Success: The Leftovers
# Success: The Letter People
# Success: The Librarians
# Success: The Listener
# Success: The Little Couple
# Success: The Long Road Home
# Success: The Lottery
# Success: The Lying Game
# Success: The Magicians
# Success: The Man in the High Castle
# Success: The Marriage Ref (UK)
# Success: The Martha Stewart Show
# Success: The Marvelous Mrs. Maisel
# Success: The Mayor
# Success: The McCarthys
# Success: The Mentalist
# Success: The Meredith Vieira Show
# Success: The Messengers
# Success: The Michael J. Fox Show
# Success: The Mick
# Success: The Middle
# Success: The Millers
# Success: The Million Second Quiz
# Success: The Mindy Project
# Success: The Missing
# Success: The Mist
# Success: The Mob Doctor
# Success: The Muppets.
# Success: The Musketeers
# Success: The Mysteries of Laura
# Success: The Neighbors
# Success: The New Adventures of Old Christine
# Success: The New Normal
# Success: The Newsroom
# Success: The Night Shift
# Success: The Nightly Show with Larry Wilmore
# Success: The Nine Lives of Chloe King
# Success: The O.C.
# Success: The OA
# Success: The Oath
# Success: The Odd Couple
# Success: The Office
# Success: The Oprah Winfrey Show
# Success: The Originals
# Success: The Orville
# Success: Star Trek: The Romulan Wars - The Outpost
# Success: The Path
# Success: The Paul Reiser Show
# Success: The Paynes
# Success: The Pete Holmes Show
# Success: The Philanthropist
# Success: Pitch
# Success: The Playboy Club
# Success: The Player
# Success: The Protector
# Success: The Quad
# Success: The Queen Latifah Show
# Success: The Quest
# Success: The Ranch
# Success: The Real Housewives of Atlanta
# Success: The Real Housewives of Beverly Hills
# Success: The Real Housewives of D.C.
# Success: The Real Housewives of Dallas
# Success: The Real Housewives of Miami
# Success: The Real Housewives of New Jersey
# Success: The Real Housewives of New York City
# Success: The Real Housewives of Orange County
# Success: The Real Housewives of Potomac
# Success: The Real L Word: Los Angeles
# Success: The Real O'Neals
# Success: Real World
# Success: The Red Road
# Success: The Resident
# Success: The Returned
# Success: The Ricki Lake Show
# Success: The Ricky Gervais Show
# Success: The River
# Success: The Royals
# Success: The Sarah Silverman Program.
# Success: The Secret Circle
# Success: The Secret Life of the American Teenager
# Success: The Shannara Chronicles
# Success: The Simpsons
# Success: The Sing-Off
# Success: The Sinner
# Success: The Sisterhood
# Success: The Slap
# Success: The Son
# Success: The Sopranos
# Success: The Soul Man
# Success: The Soup
# Success: The Strain
# Success: The Taste
# Success: The Terror
# Success: The Thundermans
# Success: The Tick
# Success: The Tomorrow People
# Success: The Toy Box
# Success: The Unit
# Success: The Unusuals
# Success: The Vampire Diaries
# Success: The Voice
# Success: The Walking Dead
# Success: Against the Wall
# Success: The Whispers
# Success: The Whole Truth
# Success: The Wil Wheaton Project
# Success: The Willis Family
# Success: The Winner Is
# Success: The World According to Paris
# Success: The X Factor
# Success: The X-Files
# Success: The X-Files
# Success: The Young and the Restless
# Success: The Young Pope
# Success: There's... Johnny!
# Success: This Is Not Happening
# Success: This Is Us
# Success: Those Who Can't
# Success: Those Who Kill
# Success: Three Rivers
# Success: Ties That Bind
# Success: 'Til Death
# Success: Time After Time
# Success: Timeless
# Success: To Tell the Truth
# Success: Toddlers and Tiaras
# Success: Togetherness
# Success: Jack Ryan
# Success: Too Close to Home
# Success: Top Chef
# Success: Top Chef: Just Desserts
# Success: Top Chef Masters
# Success: The Great Jang-Geum
# Success: Top of the Lake
# Success: Top Shot
# Success: Tori & Dean: Storibook Weddings
# Success: Tosh.0
# Success: Touch
# Success: Tracks
# Success: Traffic Light
# Success: Training Day
# Success: Transparent
# Success: Transporter: The Series
# Success: Trauma
# Success: Travelers
# Success: Treme
# Success: Trial & Error
# Success: Trophy Wife
# Success: True Beauty
# Success: True Blood
# Success: True Detective
# Success: Trust
# Success: Truth & Iliza
# Success: Truth Be Told
# Success: TURN: Washington's Spies
# Success: Twin Peaks
# Success: Twisted
# Success: Two and a Half Men
# Success: Tyrant
# Success: Ugly Americans
# Success: Ugly Betty
# Success: Ultimate Beastmaster
# Success: Unbreakable Kimmy Schmidt
# Success: Uncle Buck
# Success: Undateable
# Success: Under the Dome
# Success: Undercover
# Success: Undercover Boss
# Success: Undercovers
# Success: Underground
# Success: Unforgettable
# Success: United States of Tara
# Success: UnREAL
# Success: Untying the Knot
# Success: Up All Night
# Success: Upscale with Prentice Penny
# Success: Utopia
# Success: V
# Success: Valor
# Success: Van Helsing
# Success: Vanderpump Rules
# Success: Veep
# Success: Vegas
# Success: Veronica Mars
# Success: Vice
# Success: Vice Principals
# Success: Victorious
# Success: Vikings
# Success: Vinyl
# Success: Voltron
# Success: WAGs
# Success: Wahlburgers
# Success: Walk the Prank
# Success: Warehouse 13
# Success: Washington Heights
# Success: Wayward Pines
# Success: We Are Men
# Success: Web Therapy
# Success: Wedding Band
# Success: Weeds
# Success: Weird Loners
# Success: Welcome to Myrtle Manor
# Success: Welcome to Sweden
# Success: Welcome to the Family
# Success: Wendell and Vinnie
# Success: Westworld
# Success: What Not to Wear
# Success: What Would Ryan Lochte Do?
# Success: What Would You Do?
# Success: When Calls the Heart
# Success: White Collar
# Success: White Famous
# Success: White Gold
# Success: Whitney
# Success: Who Do You Think You Are?
# Success: Whodunnit?
# Success: Whose Line Is It Anyway?
# Success: Wicked City
# Success: Wife Swap
# Success: Wilfred
# Success: Will
# Success: Will & Grace
# Success: Wipeout
# Success: Wisdom of the Crowd
# Success: Witches of East End
# Success: Without a Trace
# Success: Work It
# Success: Workaholics
# Success: Working Class
# Success: Working the Engels
# Success: World of Dance
# Success: Wrecked
# Success: WWE Tough Enough
# Success: Wynonna Earp
# Success: You Deserve It
# Success: You Me Her
# Success: You the Jury
# Success: You're the Worst
# Success: You, Me and the Apocalypse
# Success: Young & Hungry
# Success: Young Sheldon
# Success: Younger
# Success: Your Family or Mine
# Success: Z Nation
# Success: Z: The Beginning of Everything
# Success: Zach Stone Is Gonna Be Famous
# Success: Zero Hour
# Success: The Zoo

# %%
len(feed)
# Out:
# 1573

# %% [markdown]
# Hooray! Let's save the list for safekeeping

# %%
print('Checkpoint: {} items'.format(len(feed)))
with open('feed_tmp_3.pkl', 'wb') as f:
    pickle.dump(feed, f)
# Out:
# Checkpoint: 1573 items

# %% [markdown]
# Now let's go ahead and try to wrangle this data into a dataframe!

# %%
imdb_data = pd.DataFrame(feed)
imdb_data.head()
# Out:
#                                               Actors  \
# 0  William Shatner, Jonathan Sadowski, Nicole Sul...
# 1  Michael Nyqvist, Dominic Monaghan, Felice Jank...
# 2                                Steve Jones, Nemone
# 3  Aaron Stanford, Amanda Schull, Barbara Sukowa,...
# 4  Nina Cheek, Michael Sadler, Cassie Hendry, Ke'...
#
#                                               Awards BoxOffice  \
# 0                                             1 win.       NaN
# 1                                      1 nomination.       NaN
# 2                                                N/A       NaN
# 3                            4 wins & 8 nominations.       NaN
# 4  Nominated for 1 Golden Globe. Another 2 wins &...       NaN
#
#            Country  DVD Director                      Genre          Language  \
# 0              USA  NaN      N/A                     Comedy           English
# 1  Sweden, Germany  NaN      N/A                      Crime  Swedish, English
# 2    UK, Argentina  NaN      N/A                  Game-Show           English
# 3              USA  NaN      N/A  Adventure, Drama, Mystery           English
# 4              USA  NaN      N/A             Drama, Mystery           English
#
#   Metascore                                               Plot     ...       \
# 0       N/A  This show is about Ed Goodson a very old fashi...     ...
# 1       N/A  New York, USA. Stockholm, Sweden. Over the pas...     ...
# 2       N/A  People must answere questions correctly and if...     ...
# 3       N/A  Follows the journey of a time traveler from th...     ...
# 4       N/A  Thirteen Reasons Why, based on the best-sellin...     ...
#
#   Runtime                         Title    Type Website  \
# 0  30 min              $#*! My Dad Says  series     NaN
# 1  60 min                      100 Code  series     NaN
# 2     N/A  101 Ways to Leave a Gameshow  series     NaN
# 3  42 min                    12 Monkeys  series     NaN
# 4  60 min                13 Reasons Why  series     NaN
#
#                                               Writer       Year     imdbID  \
# 0  Justin Halpern, David Kohan, Max Mutchnick, Pa...  2010–2011  tt1612578
# 1                                      Bobby Moresco      2015–  tt3515512
# 2                                                N/A      2010–  tt1702030
# 3                      Travis Fickett, Terry Matalas      2015–  tt3148266
# 4                                       Brian Yorkey      2017–  tt1837492
#
#   imdbRating imdbVotes totalSeasons
# 0        6.3     4,647            1
# 1        7.4     2,101            1
# 2        5.7        48          N/A
# 3        7.6    29,731            4
# 4        8.3   163,320            2
#
# [5 rows x 26 columns]

# %%
# Renaming columns...
newcols = []
for col in imdb_data.columns:
    if 'imdb' in col:
        col = col.strip('imdb')
    col = 'imdb_'+col
    col = col.lower()
    newcols.append(col)
    
imdb_data.columns = newcols
print(imdb_data.columns)
# Out:
# Index(['imdb_actors', 'imdb_awards', 'imdb_boxoffice', 'imdb_country',
#        'imdb_dvd', 'imdb_director', 'imdb_genre', 'imdb_language',
#        'imdb_metascore', 'imdb_plot', 'imdb_poster', 'imdb_production',
#        'imdb_rated', 'imdb_ratings', 'imdb_released', 'imdb_response',
#        'imdb_runtime', 'imdb_title', 'imdb_type', 'imdb_website',
#        'imdb_writer', 'imdb_year', 'imdb_id', 'imdb_rating', 'imdb_votes',
#        'imdb_totalseasons'],
#       dtype='object')

# %%
shows.columns
# Out:
# Index(['genre', 'link', 'network', 'status', 'tagline', 'title', 'years',
#        'start_year', 'end_year', 'synopsis', 'primary_genre',
#        'secondary_genre', 'Comedy', 'Drama', 'Game Show', 'Reality', 'Sci-fi',
#        'Talk', 'Crime', 'Action', 'Fantasy', 'Animated', 'Horror', 'Legal',
#        'Medical', 'tvmaze_name', 'tvmaze_tv_id', 'imdb_id', 'tvmaze_prem_date',
#        'tvmaze_rating', 'tvmaze_runtime', 'tvmaze_ep_day'],
#       dtype='object')

# %%
shows = shows.merge(imdb_data,how='left',on='imdb_id')

# %%
shows.columns
# Out:
# Index(['genre', 'link', 'network', 'status', 'tagline', 'title', 'years',
#        'start_year', 'end_year', 'synopsis', 'primary_genre',
#        'secondary_genre', 'Comedy', 'Drama', 'Game Show', 'Reality', 'Sci-fi',
#        'Talk', 'Crime', 'Action', 'Fantasy', 'Animated', 'Horror', 'Legal',
#        'Medical', 'tvmaze_name', 'tvmaze_tv_id', 'imdb_id', 'tvmaze_prem_date',
#        'tvmaze_rating', 'tvmaze_runtime', 'tvmaze_ep_day', 'imdb_actors',
#        'imdb_awards', 'imdb_boxoffice', 'imdb_country', 'imdb_dvd',
#        'imdb_director', 'imdb_genre', 'imdb_language', 'imdb_metascore',
#        'imdb_plot', 'imdb_poster', 'imdb_production', 'imdb_rated',
#        'imdb_ratings', 'imdb_released', 'imdb_response', 'imdb_runtime',
#        'imdb_title', 'imdb_type', 'imdb_website', 'imdb_writer', 'imdb_year',
#        'imdb_rating', 'imdb_votes', 'imdb_totalseasons'],
#       dtype='object')

# %%
shows[shows['imdb_id'].isnull()]
# Out:
#          genre                                               link  \
# 305  Game Show  http://www.ismyshowcancelled.com/show/2009/cra...
# 632    Reality  http://www.ismyshowcancelled.com/show/2015/ink...
#
#                network     status  \
# 305                ABC  Cancelled
# 632  Paramount Network     On Air
#
#                                                tagline  \
# 305  A reality show where teams get behind the driv...
# 632  A spin-off series offering former Ink Master t...
#
#                       title           years  start_year  end_year  \
# 305            Crash Course     2009 - 2013        2009    2013.0
# 632  Ink Master: Redemption  2015 - Present        2015       NaN
#
#                                               synopsis        ...          \
# 305  In each episode of Crash Course, five teams of...        ...
# 632  What happens to the disgruntled human canvases...        ...
#
#     imdb_response imdb_runtime  imdb_title  imdb_type  imdb_website  \
# 305           NaN          NaN         NaN        NaN           NaN
# 632           NaN          NaN         NaN        NaN           NaN
#
#      imdb_writer  imdb_year  imdb_rating  imdb_votes  imdb_totalseasons
# 305          NaN        NaN          NaN         NaN                NaN
# 632          NaN        NaN          NaN         NaN                NaN
#
# [2 rows x 57 columns]

# %% [markdown]
# Above are the two that didn't have good matches on IMDB (as discussed on OMDB). They still seemed to have been merged fine.
#
# Let's checkpoint to pickle...

# %%
shows.to_pickle("full_shows_tmp_2_tvmaze+imdb.pkl")

# %%
shows = pd.read_pickle("full_shows_tmp_2_tvmaze+imdb.pkl")

# %%
len(shows)
# Out:
# 1603

# %%
shows['title'].value_counts()
# Out:
# Deception                            4
# The Bridge                           4
# Star-Crossed                         2
# Face Off                             2
# @midnight                            2
# Million Dollar Listing New York      2
# Still Star-Crossed                   2
# Alexa & Katie                        2
# Million Dollar Listing               2
# The X-Files                          2
# The Wall                             2
# The X-Files (2016)                   2
# Midnight, Texas                      2
# Being Mary Jane                      2
# Against The Wall                     2
# Love & Hip Hop: Atlanta              2
# Love & Hip Hop                       2
# Pitch                                2
# Katie                                2
# Mary + Jane                          2
# Missing                              2
# The Face                             2
# The Pitch                            2
# Scream                               2
# Scream Queens                        2
# The Missing                          2
# Grey's Anatomy                       1
# Great News                           1
# Gravity Falls                        1
# Greek                                1
#                                     ..
# Sex&Drugs&Rock&Roll                  1
# Sexy Beasts                          1
# Shades of Blue                       1
# Shadowhunters                        1
# Shahs of Sunset                      1
# Schitt's Creek                       1
# Scandal                              1
# Rush                                 1
# Samantha Who?                        1
# Rush Hour                            1
# S.W.A.T.                             1
# SEAL Team                            1
# SMILF                                1
# SWV Reunited                         1
# Safe                                 1
# Salem                                1
# Salvation                            1
# Sam & Cat                            1
# Same Name                            1
# Say Yes to the Dress: Bridesmaids    1
# Sanctuary                            1
# Santa Clarita Diet                   1
# Sarah Palin's Alaska                 1
# Satisfaction                         1
# Saturday Night Live                  1
# Save Me                              1
# Saving Grace                         1
# Saving Hope                          1
# Say Yes to the Dress: Atlanta        1
# $#*! My Dad Says                     1
# Name: title, Length: 1573, dtype: int64

# %% [markdown]
# Looks like we did have a couple weird instances where a show showed up multiple times. Let's clear those up.

# %%
cleaner = shows.copy()
cleaner['ones'] = 1
shows['title_cumsum'] = cleaner.groupby('title')['ones'].transform(np.cumsum)
shows['title_dupes'] = cleaner.groupby('title')['ones'].transform('count')
shows['imdbid_dupes'] = cleaner.groupby('title')['ones'].transform('count')
shows['imdbid_cumsum'] = cleaner.groupby('title')['ones'].transform(np.cumsum)

# %%
shows = shows[(shows['imdbid_cumsum'] == 1) | (shows['imdbid_cumsum'].isnull())]

# %%
shows.shape
# Out:
# (1573, 61)

# %% [markdown]
# Looks like we're back to the right number. Pickling again - next, data cleaning & exploration!

# %%
shows = shows.drop(['title_cumsum','title_dupes','imdbid_dupes','imdbid_cumsum'],axis=1)
shows.columns
# Out:
# Index(['genre', 'link', 'network', 'status', 'tagline', 'title', 'years',
#        'start_year', 'end_year', 'synopsis', 'primary_genre',
#        'secondary_genre', 'Comedy', 'Drama', 'Game Show', 'Reality', 'Sci-fi',
#        'Talk', 'Crime', 'Action', 'Fantasy', 'Animated', 'Horror', 'Legal',
#        'Medical', 'tvmaze_name', 'tvmaze_tv_id', 'imdb_id', 'tvmaze_prem_date',
#        'tvmaze_rating', 'tvmaze_runtime', 'tvmaze_ep_day', 'imdb_actors',
#        'imdb_awards', 'imdb_boxoffice', 'imdb_country', 'imdb_dvd',
#        'imdb_director', 'imdb_genre', 'imdb_language', 'imdb_metascore',
#        'imdb_plot', 'imdb_poster', 'imdb_production', 'imdb_rated',
#        'imdb_ratings', 'imdb_released', 'imdb_response', 'imdb_runtime',
#        'imdb_title', 'imdb_type', 'imdb_website', 'imdb_writer', 'imdb_year',
#        'imdb_rating', 'imdb_votes', 'imdb_totalseasons'],
#       dtype='object')

# %%
shows.to_pickle("full_shows_tmp_6_tvmaze+imdb.pkl")

# %%
shows = pd.read_pickle("full_shows_tmp_6_tvmaze+imdb.pkl")
