# %% [markdown]
# Before we do a full pull from OMDB, we'll need to ping the OMDB API for any shows for which we couldn't pick up an IMDB ID from TVMaze (which generally has better search matching than OMDB). To do this, we need to be very careful about timing. I've written a custom wrapper and requests function that sleeps if a request times out due to server overload, such that the dataset does not need to be gathered piecemeal.

# %%
import pandas as pd
import numpy as np
import requests
import time
import re
from functools import wraps
import yaml
shows = pd.read_pickle("ismyshowcancelled_final.pkl")
tvmaze = pd.read_csv("tvmaze_tmp_3.csv",index_col=0)
auth = yaml.load(open('omdb.yaml'))
key = auth['OMDB']['Key']

# %% [markdown]
# There's about ~170 shows that don't have an IMDB ID according to tvmaze. I suspect, though, that this is a shortcoming in their database and not an actual indication that IMDB has no record of these shows. Let's first get a list of the ones we want to search for.

# %%
# This dataframe is going to house the shows with missing IMDB IDs, 
# as well as the IDs that we eventually (hopefully) will return
missing_imdb = pd.DataFrame(tvmaze[tvmaze['imdb'].isnull()]['name'])
missing_imdb['found_id'] = np.nan
missing_imdb['found_name'] = np.nan
missing_imdb.head()
# Out:
#                          name  found_id  found_name
# 301  Crash Course Engineering       NaN         NaN
# 625    Ink Master: Redemption       NaN         NaN

# %%
# A wrapper to retry the request function many times, with a sleep in between
def retry_multi(max_retries):
    """ Retry a function `max_retries` times. """
    def retry(func):
        @wraps(func)
        def wrapper(*args, **kwargs):
            num_retries = 0 
            while num_retries <= max_retries:
                try:
                    ret = func(*args, **kwargs)
                    break
                except:
                    if num_retries == max_retries:
                        raise
                    num_retries += 1
                    time.sleep(15)
            return ret 
        return wrapper
    return retry

# %%
# Building a requester for the IMDB IDs from OMDB (note that this differs from our tvmaze equivalent function)
@retry_multi(10)
def request_info(show):
    
    # proper formatting
    show = '-'.join(show.lower().split()).replace(':','')
    
    # define params for json request
    params = {'apikey':key,'t':show,'type':'series'}

    # send request via requests
    response = requests.get('http://www.omdbapi.com/?',params=params)
    
    return response

# %%
# Building functions to extract just the IMDB IDs and names (just to cross-check that the result wasn't erroneous)
# Later, we'll return to scrape all the information we want once we have a dataframe filled with necessary IDs
def get_json(response):
    
    # Just return the json, if the search was successful
    if response.json()['Response'] == 'True':
        success = True
    elif response.json()['Response'] == 'False':
        success = False
        
    # Return a dict indicating success/failure of request, with json
    return {'json':response.json(), 'success':success}

# %%
def extract_imdb(json_response):
    
    # get the id, if successful pull
    if json_response['success'] == True:
        return(json_response['json']['imdbID'])

def extract_title(json_response):
    
    # get the name, if successful pull. this is just for cross-checking and we'll delete it later
    if json_response['success'] == True:
        return(json_response['json']['Title'])

# %%
# Now writing a loop to ping for requests!
for show,index in zip(missing_imdb.name,missing_imdb.index):
    
    # Request the show from OMDB
    r = request_info(show)
    json_response = get_json(r)
    
    # Getting imdb id and title (will not collect anything if unsuccessful json response)
    imdb = extract_imdb(json_response)
    title = extract_title(json_response)
    
    # Doing a double check (also in function) that we got a good response, then inputting info back into our df
    if json_response['success'] is True:
        
        # Letting us know what happened
        print('Match for {}: {}. ID is {}'.format(show,title,imdb))
        
        # Adding this result back to our dataframe
        missing_imdb.loc[missing_imdb.index == index,'found_name'] = title
        missing_imdb.loc[missing_imdb.index == index,'found_id'] = imdb
        #missing_imdb.iloc[index].loc['found_id'] = imdb
# Match for Z: The Beginning of Everything: Z: The Beginning of Everything. ID is tt4878612

# %%
missing_imdb.tail(30)
# Out:
#                                  name   found_id  \
# 1305                  The Hasselhoffs  tt1705811
# 1308                      The Insider  tt0430836
# 1311             The Jeff Probst Show  tt1978332
# 1313           The Jim Jefferies Show  tt6987966
# 1324                  The Last Tycoon  tt3390892
# 1327                       The Letter  tt0285289
# 1331               The Long Road Home  tt1210820
# 1348          The Million Second Quiz  tt3038492
# 1370                      The Orville  tt5691552
# 1371                      The Outpost  tt5331942
# 1382           The Queen Latifah Show  tt2099467
# 1400              The Ricki Lake Show  tt1908423
# 1421                         The Tick  tt5540054
# 1423                      The Toy Box  tt6392176
# 1429                         The Wall  tt1836237
# 1434                 The Winner Is...  tt2341735
# 1441               There's... Johnny!  tt6483198
# 1442            This is Not Happening  tt3528306
# 1446                     Three Rivers  tt1440346
# 1455                Too Close to Home  tt5596646
# 1462  Tori & Dean: sTORIbook Weddings  tt1705812
# 1465                           Tracks  tt0310534
# 1479                    Truth & Iliza  tt6847436
# 1488             Ultimate Beastmaster  tt5607970
# 1502      Upscale with Prentice Penny  tt6668854
# 1509                      Vegas Cakes        NaN
# 1519                   Walk the Prank  tt5486088
# 1534       What Would Ryan Lochte Do?  tt2798842
# 1547                             Will  tt5734140
# 1571   Z: The Beginning of Everything  tt4878612
#
#                                      found_name
# 1305                            The Hasselhoffs
# 1308                                The Insider
# 1311                       The Jeff Probst Show
# 1313                     The Jim Jefferies Show
# 1324                            The Last Tycoon
# 1327                          The Letter People
# 1331                         The Long Road Home
# 1348                    The Million Second Quiz
# 1370                                The Orville
# 1371  Star Trek: The Romulan Wars - The Outpost
# 1382                     The Queen Latifah Show
# 1400                        The Ricki Lake Show
# 1421                                   The Tick
# 1423                                The Toy Box
# 1429                           Against the Wall
# 1434                              The Winner Is
# 1441                         There's... Johnny!
# 1442                      This Is Not Happening
# 1446                               Three Rivers
# 1455                          Too Close to Home
# 1462            Tori & Dean: Storibook Weddings
# 1465                                     Tracks
# 1479                              Truth & Iliza
# 1488                       Ultimate Beastmaster
# 1502                Upscale with Prentice Penny
# 1509                                        NaN
# 1519                             Walk the Prank
# 1534                 What Would Ryan Lochte Do?
# 1547                                       Will
# 1571             Z: The Beginning of Everything

# %% [markdown]
# Success! We got a good number of matches, and the leftovers are few enough that I can do a quick check for the remainder and just write those into the CSV. Additionally, those matches we did get seem entirely accurate.
#
# For now, we'll add these IMDB IDs back into the original dataframe nad go from there!

# %%
for show in missing_imdb['name']:
    tvmaze.loc[tvmaze['name'] == show,'imdb'] = missing_imdb.loc[missing_imdb['name'] == show,'found_id']

# %% [markdown]
# Doing some spot checking...

# %%
tvmaze.loc[tvmaze['name'] == 'The Hasselhoffs','imdb']
# Out:
# 1305    tt1705811
# Name: imdb, dtype: object

# %%
tvmaze.loc[tvmaze['name'] == 'The Outpost']
# Out:
#              name    tv_id       imdb   prem_date  rating  runtime   ep_day
# 1371  The Outpost  34419.0  tt5331942  2018-07-10     NaN     60.0  Tuesday

# %%
tvmaze.isnull().sum()
# Out:
# name           5
# tv_id          5
# imdb           8
# prem_date     12
# rating       466
# runtime       13
# ep_day         5
# dtype: int64

# %%
tvmaze[tvmaze['imdb'].isnull()]
# Out:
#                                      name    tv_id imdb   prem_date  rating  \
# 141    Ben and Lauren: Happily Ever After  20882.0  NaN  2016-10-11     NaN
# 151                  Bethenny and Fredrik  27702.0  NaN  2018-02-06     NaN
# 204   Brandi & Jarrod: Married to the Job  15352.0  NaN  2014-08-12     NaN
# 301              Crash Course Engineering  36786.0  NaN         NaN     NaN
# 625                Ink Master: Redemption   3097.0  NaN  2015-09-08     NaN
# 808                        Me, Myself & I  20660.0  NaN  2017-09-25     6.5
# 872           Nate and Jeremiah by Design  25890.0  NaN  2017-04-08     NaN
# 1509                          Vegas Cakes  33303.0  NaN  2017-11-05     NaN
#
#       runtime    ep_day
# 141      60.0   Tuesday
# 151      30.0   Tuesday
# 204      30.0   Tuesday
# 301       NaN  Multiple
# 625      30.0   Tuesday
# 808      30.0    Monday
# 872      60.0  Saturday
# 1509     30.0  Multiple

# %% [markdown]
# Awesome, we've greatly reduced the number of missing IDs. Let's save this to CSV and then I'll fill in the remainder myself.

# %%
tvmaze.to_csv("tvmaze_tmp_4_more_ids.csv")

# %% [markdown]
# I found matches for all but 2: Ink Master Redemption (which is considered to be the same thing as Ink Master by IDMB, which we already have in our dataset), and Crash Course Engineering (this is a YouTube series). We'll probably delete both once we get into the analysis and modeling phases.

# %%
tvmaze[tvmaze['tvmaze_name']=='Caprica']
# Out:
#     tvmaze_name  tvmaze_tv_id    imdb_id tvmaze_prem_date  tvmaze_rating  \
# 234     Caprica         433.0  tt0799862       2010-01-22            7.4
#
#      tvmaze_runtime tvmaze_ep_day
# 234            60.0       Tuesday

# %%
tvmaze = pd.read_csv("tvmaze_tmp_5_more_ids_MORE ADDITIONS.csv",index_col=0)

# %%
tvmaze.isnull().sum()
# Out:
# name           5
# tv_id          6
# imdb           2
# prem_date     12
# rating       466
# runtime       13
# ep_day         5
# dtype: int64

# %% [markdown]
# Awesome! Only one thing remains for now. Let's merge this with our shows df. Luckily, they rely on the exact same indices.

# %%
l = []
for col in tvmaze.columns:
    l.append('tvmaze_'+col)

# %%
l
# Out:
# ['tvmaze_name',
#  'tvmaze_tv_id',
#  'tvmaze_imdb',
#  'tvmaze_prem_date',
#  'tvmaze_rating',
#  'tvmaze_runtime',
#  'tvmaze_ep_day']

# %%
l[2] = 'imdb_id'

# %%
l
# Out:
# ['tvmaze_name',
#  'tvmaze_tv_id',
#  'imdb_id',
#  'tvmaze_prem_date',
#  'tvmaze_rating',
#  'tvmaze_runtime',
#  'tvmaze_ep_day']

# %%
tvmaze.columns = l

# %%
tvmaze.head()
# Out:
#                     tvmaze_name  tvmaze_tv_id    imdb_id tvmaze_prem_date  \
# 0              $#*! My Dad Says        1986.0  tt1612578        9/23/2010
# 1                      100 Code        3953.0  tt3515512        3/11/2015
# 2  101 Ways to Leave a Gameshow       12166.0  tt1702030        7/10/2010
# 3                    12 Monkeys         614.0  tt3148266        1/16/2015
# 4                13 Reasons Why        7194.0  tt1837492        3/31/2017
#
#    tvmaze_rating  tvmaze_runtime tvmaze_ep_day
# 0            6.2            30.0      Thursday
# 1            8.1            60.0     Wednesday
# 2            NaN            60.0      Saturday
# 3            7.9            60.0        Friday
# 4            8.2            60.0        Friday

# %%
tvmaze.isnull().sum()
# Out:
# tvmaze_name           5
# tvmaze_tv_id          6
# imdb_id               2
# tvmaze_prem_date     12
# tvmaze_rating       466
# tvmaze_runtime       13
# tvmaze_ep_day         5
# dtype: int64

# %%
tvmaze.iloc[234:]
# Out:
#                          tvmaze_name  tvmaze_tv_id    imdb_id  \
# 234                          Caprica         433.0  tt0799862
# 235                      The Capture       35512.0  tt1100911
# 236                         Cardinal       18613.0  tt5583512
# 237                         Cash Cab        8327.0  tt0465321
# 238                           Castle          68.0  tt1219024
# 239                      Castlevania       25242.0  tt6517102
# 240                           Casual        3036.0  tt4577466
# 241                      Catastrophe        3004.0  tt4374208
# 242               Catch a Contractor        2287.0  tt3108438
# 243             Catfish: The TV Show         997.0  tt2498968
# 244                       Cedar Cove        2489.0  tt2871832
# 245           Cedric's Barber Battle        1592.0  tt4346996
# 246      CeeLo Green's The Good Life       25900.0  tt3774098
# 247            Celebrity Big Brother       31713.0  tt0279550
# 248            Celebrity Family Feud        2212.0  tt1249208
# 249    Celebrity Rehab with Dr. Drew        6989.0  tt1114705
# 250              Celebrity Wife Swap        1783.0  tt2125758
# 251                        Champions       28166.0  tt6470396
# 252                           Chance       11307.0  tt5620076
# 253                     Channel Zero        8706.0  tt4820370
# 254                            Chaos         971.0  tt1591468
# 255                 Charlie's Angels         447.0  tt1760943
# 256                        The Chase        8574.0  tt1502749
# 257                     Chasing Life         298.0  tt2399794
# 258                 Cheer Perfection        9596.0  tt2301076
# 259                      Cheer Squad       15320.0  tt5993744
# 260                 Chef Roblé & Co.       14350.0  tt1879801
# 261                     Chef's Table        3252.0  tt4295140
# 262                          Chelsea       16628.0  tt5672036
# 263                Chesapeake Shores        6744.0  tt5151816
# ...                              ...           ...        ...
# 1545                       Wife Swap       25006.0  tt0392948
# 1546                         Wilfred         556.0  tt1703925
# 1547                            Will       13356.0  tt5734140
# 1548                    Will & Grace         549.0  tt0157246
# 1549                         Wipeout         980.0  tt1156535
# 1550             Wisdom of the Crowd       25177.0  tt6522758
# 1551             Witches of East End          47.0  tt2288064
# 1552                 Without a Trace         813.0  tt0321021
# 1553                         Work It        4893.0  tt1826951
# 1554                     Workaholics         370.0  tt1610527
# 1555                   Working Class        7785.0  tt1707394
# 1556              Working the Engels        5596.0  tt3489108
# 1557                  World of Dance       21599.0  tt5895884
# 1558                         Wrecked        3590.0  tt4168956
# 1559                WWE Tough Enough        4703.0  tt2026808
# 1560                    Wynonna Earp        6767.0  tt4878326
# 1561                  You Deserve It       14355.0  tt1910674
# 1562                      You Me Her        8865.0  tt5179408
# 1563                    You the Jury       25944.0  tt6723012
# 1564                You're the Worst         312.0  tt3228420
# 1565      You, Me and the Apocalypse        2948.0  tt4337894
# 1566                  Young & Hungry        1745.0  tt2084712
# 1567                   Young Sheldon       26020.0  tt6226232
# 1568                         Younger         623.0  tt3288518
# 1569             Your Family or Mine        1740.0  tt3597660
# 1570                        Z Nation          38.0  tt3843168
# 1571  Z: The Beginning of Everything       10801.0  tt4878612
# 1572   Zach Stone is Gonna Be Famous        7809.0  tt1748277
# 1573                       Zero Hour        1010.0  tt2215797
# 1574                         The Zoo       25067.0  tt6440422
#
#      tvmaze_prem_date  tvmaze_rating  tvmaze_runtime tvmaze_ep_day
# 234         1/22/2010            7.4            60.0       Tuesday
# 235               NaN            NaN            60.0      Multiple
# 236         1/25/2017            7.9            60.0      Thursday
# 237         6/13/2005            NaN            30.0        Monday
# 238          3/9/2009            8.4            60.0        Monday
# 239          7/7/2017            7.1            30.0        Friday
# 240         10/7/2015            7.4            30.0       Tuesday
# 241         1/19/2015            8.2            35.0       Tuesday
# 242          3/9/2014            NaN            60.0        Sunday
# 243        11/12/2012            7.3            60.0     Wednesday
# 244         7/20/2013            7.3            60.0      Saturday
# 245         4/17/2015            NaN            30.0        Monday
# 246         6/23/2014            NaN            30.0        Monday
# 247          2/7/2018            4.5            60.0      Multiple
# 248         6/21/2015            NaN            60.0        Sunday
# 249         1/10/2008            NaN            60.0     Wednesday
# 250          1/2/2012            NaN            60.0     Wednesday
# 251          3/8/2018            4.7            30.0      Thursday
# 252        10/19/2016            8.2            60.0     Wednesday
# 253        10/11/2016            7.0            60.0     Wednesday
# 254          4/1/2011            7.8            60.0      Saturday
# 255         9/22/2011            7.2            60.0      Thursday
# 256         6/29/2009            NaN            60.0      Multiple
# 257         6/10/2014            7.4            60.0        Monday
# 258        12/19/2012            NaN            60.0     Wednesday
# 259         8/22/2016            NaN            60.0      Multiple
# 260         12/4/2011            NaN            60.0     Wednesday
# 261         4/26/2015            8.8            50.0        Friday
# 262         5/11/2016            7.5            30.0        Friday
# 263         8/14/2016            7.9            60.0        Sunday
# ...               ...            ...             ...           ...
# 1545         1/1/2003            NaN            60.0        Monday
# 1546        6/23/2011            7.7            30.0      Multiple
# 1547        7/10/2017            5.5            60.0        Monday
# 1548        9/21/1998            7.4            30.0      Thursday
# 1549        6/24/2008            NaN            60.0        Sunday
# 1550        10/1/2017            6.9            60.0        Sunday
# 1551        10/6/2013            7.7            60.0        Sunday
# 1552        9/26/2002            8.0            60.0      Multiple
# 1553         1/3/2012            NaN            30.0       Tuesday
# 1554         4/6/2011            7.8            30.0     Wednesday
# 1555        1/28/2011            NaN            30.0        Friday
# 1556        7/10/2014            NaN            30.0     Wednesday
# 1557        5/30/2017            8.5            60.0       Tuesday
# 1558        6/14/2016            6.2            30.0       Tuesday
# 1559        6/21/2001            NaN             NaN      Multiple
# 1560         4/1/2016            7.2            60.0        Friday
# 1561       11/21/2011            NaN            60.0        Monday
# 1562        3/22/2016            8.1            30.0       Tuesday
# 1563         4/7/2017            NaN            60.0        Friday
# 1564        7/17/2014            7.8            30.0     Wednesday
# 1565        9/30/2015            8.1            60.0      Thursday
# 1566        6/25/2014            7.6            30.0        Monday
# 1567        9/25/2017            7.5            30.0      Thursday
# 1568        3/31/2015            7.5            30.0     Wednesday
# 1569         4/7/2015            7.0            30.0       Tuesday
# 1570        9/12/2014            7.2            60.0        Friday
# 1571        11/5/2015            6.9            60.0        Friday
# 1572         5/2/2013            NaN            30.0      Thursday
# 1573        2/14/2013            7.6            60.0      Saturday
# 1574        2/18/2017            7.5            60.0      Saturday
#
# [1341 rows x 7 columns]

# %%
shows = shows.join(tvmaze)

# %%
shows.head()
# Out:
#             genre                                               link  \
# 0          Comedy  http://www.ismyshowcancelled.com/show/2010/ble...
# 1   Drama / Crime  http://www.ismyshowcancelled.com/show/2018/100...
# 2       Game Show  http://www.ismyshowcancelled.com/show/2011/101...
# 3  Drama / Sci-fi  http://www.ismyshowcancelled.com/show/2015/12-...
# 4           Drama  http://www.ismyshowcancelled.com/show/2017/13-...
#
#        network       status  \
# 0          CBS    Cancelled
# 1  WGN America  Coming Soon
# 2          ABC    Cancelled
# 3         Syfy       On Air
# 4      Netflix       On Air
#
#                                              tagline  \
# 0  A sitcom based on the Twitter feed "S*** My Da...
# 1  A thriller following an New York cop who trave...
# 2  A game show competition where contestants are ...
# 3  A drama following a man sent back in time to p...
# 4  A drama following the revelation of why a youn...
#
#                           title           years  start_year  end_year  \
# 0              $#*! My Dad Says     2010 - 2011        2010    2011.0
# 1                      100 Code  2018 - Present        2018       NaN
# 2  101 Ways to Leave a Gameshow     2011 - 2011        2011    2011.0
# 3                    12 Monkeys  2015 - Present        2015       NaN
# 4                13 Reasons Why  2017 - Present        2017       NaN
#
#                                             synopsis      ...       Horror  \
# 0  Ed is an opinionated and divorced 72-year-old ...      ...            0
# 1  NYPD Detective Tommy Conley travels to Sweden ...      ...            0
# 2  In 101 Ways to Leave a Game Show, contestants ...      ...            0
# 3  By the year 2043, a deadly virus has wiped out...      ...            0
# 4  Hannah Baker is a teenage girl who takes her o...      ...            0
#
#   Legal  Medical                   tvmaze_name  tvmaze_tv_id    imdb_id  \
# 0     0        0              $#*! My Dad Says        1986.0  tt1612578
# 1     0        0                      100 Code        3953.0  tt3515512
# 2     0        0  101 Ways to Leave a Gameshow       12166.0  tt1702030
# 3     0        0                    12 Monkeys         614.0  tt3148266
# 4     0        0                13 Reasons Why        7194.0  tt1837492
#
#    tvmaze_prem_date  tvmaze_rating  tvmaze_runtime  tvmaze_ep_day
# 0         9/23/2010            6.2            30.0       Thursday
# 1         3/11/2015            8.1            60.0      Wednesday
# 2         7/10/2010            NaN            60.0       Saturday
# 3         1/16/2015            7.9            60.0         Friday
# 4         3/31/2017            8.2            60.0         Friday
#
# [5 rows x 32 columns]

# %% [markdown]
# Saving to pkl and csv...

# %%
shows.to_csv("full_shows_tmp_1_tvmaze_plus_imdbids.csv")

# %%
shows.to_pickle("full_shows_tmp_1_tvmaze_plus_imdbids.pkl")

# %%
shows.shape
# Out:
# (1575, 32)

# %%
shows.isnull().sum()
# Out:
# genre                  0
# link                   0
# network                0
# status                 0
# tagline                0
# title                  0
# years                  0
# start_year             0
# end_year             595
# synopsis               0
# primary_genre          0
# secondary_genre     1070
# Comedy                 0
# Drama                  0
# Game Show              0
# Reality                0
# Sci-fi                 0
# Talk                   0
# Crime                  0
# Action                 0
# Fantasy                0
# Animated               0
# Horror                 0
# Legal                  0
# Medical                0
# tvmaze_name            5
# tvmaze_tv_id           6
# imdb_id                2
# tvmaze_prem_date      12
# tvmaze_rating        466
# tvmaze_runtime        13
# tvmaze_ep_day          5
# dtype: int64
